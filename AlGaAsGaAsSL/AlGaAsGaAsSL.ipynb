# %%
import nextnanopy as nn
import os
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
path_nextnanoprojects_tools = r"C:\Users\sp6497_a\nextnanopy_projects"

# %%
print(sys.path)
sys.path.append(path_nextnanoprojects_tools)
print(sys.path)
from nextnano_tools.helper_functions import build_output
from nextnano_tools.simstructs import SimOut, BandStructure, Eigenstate
# Out:
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\sp6497_a\\nextnanopy_projects', 'C:\\Users\\sp6497_a\\nextnanopy_projects', 'C:\\Users\\sp6497_a\\nextnanopy_projects']
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\sp6497_a\\nextnanopy_projects', 'C:\\Users\\sp6497_a\\nextnanopy_projects', 'C:\\Users\\sp6497_a\\nextnanopy_projects', 'C:\\Users\\sp6497_a\\nextnanopy_projects']

# %%
bias = r'bias_00000'
quantum_region = r'Quantum\quantum_region'
quantum_band = r'Gamma'
quantum_band_interactions = r'Gamma_Gamma'

# %%
# %matplotlib widget
parent_dir = r"C:\Users\sp6497_a\OneDrive - Princeton University\nextnano_outs\Output\xcheck_SL(15)"

# simoutidk = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,14,model='kp') #multiband pass in case
simoutidk = build_output(parent_dir,quantum_region,bias,model='1band')
simoutidk.bands['Gamma'].sort_subbands(decreasing=False)

# N_arrayx = simoutidk.variables['N_arrayx']
N_periods = simoutidk.variables['N_periods']
temp = simoutidk.variables['temp']
# temp = 5.0
dop_cc = simoutidk.variables['impurity_conc_cc']
Al_x = simoutidk.variables['Al_alloy']
act_E_AlaAs = simoutidk.variables['activation_E_AlAs']
act_E_GaAs = simoutidk.variables['activation_E_GaAs']
# Nd_GaAs_wall = simoutidk.variables['GaAs_wall_cc']
# surrounding_cc = simoutidk.variables['GaAs_wall_cc']
# base_title = str(N_periods) + ' periods, T =' + str(temp) + ' K, Alx ='  + str(Al_x) + ', $t_{well}$= ' +str(simoutidk.variables['w_well']) + ' nm, $t_{barrier}$='+ str(simoutidk.variables['w_barrier']) + ' nm'+'\n Nd = ' + str(dop_cc) + ' cm^-3, Nd_GaAs_wall = ' + str(Nd_GaAs_wall) + ' cm^-3, $E_{act,AlGaAs}=$ ' + str(act_E_AlaAs) + ' eV, $E_{act,GaAs}=$ ' + str(act_E_GaAs) + ' eV'
base_title = str(N_periods+1) + ' periods, T =' + str(temp) + ' K, Alx ='  + str(Al_x) + ', $t_{well}$= ' +str(simoutidk.variables['w_well']) + ' nm, $t_{barrier}$='+ str(simoutidk.variables['w_barrier']) + ' nm'+'\n Nd = ' + str(dop_cc) + ' cm^-3, $E_{act,AlGaAs}=$ ' + str(act_E_AlaAs) + ' eV, $E_{act,GaAs}=$ ' + str(act_E_GaAs) + ' eV'

[fig_plot,ax_plot] = simoutidk.bands['Gamma'].plot_band(title_diff=base_title,normalize_y=False,show_legend=False,fontsizetitle=16)
# ax_plot.set_ylabel('Energy relative to ')
# ax_plot.set_xlim(-30,190)
simoutidk.bands['Gamma'].calc_intersubband_transitions()
simoutidk.bands['Gamma'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")

# simoutidk.optical_absorption.get_spectrum('TM-z').plot(diff_title = base_title + ' absorption',show_grid=True,fontsizetitle=12)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Intersubband transition energies — Gamma
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   2 →  3 | -0.0000
#   4 →  5 | -0.0001
#   6 →  7 | -0.0001
#   8 →  9 | -0.0002
#  18 → 19 | -0.0004
#  12 → 13 | -0.0006
#  16 → 17 | -0.0006
#  14 → 15 | -0.0007
#   1 →  2 | -0.0009
#   1 →  3 | -0.0010
#   9 → 10 | -0.0013
#   8 → 10 | -0.0014
#   3 →  4 | -0.0025
#   2 →  4 | -0.0026
#   3 →  5 | -0.0027
#   2 →  5 | -0.0027
#   7 →  8 | -0.0031
#   6 →  8 | -0.0032
#   7 →  9 | -0.0032
#   6 →  9 | -0.0034
#   5 →  6 | -0.0034
#   1 →  4 | -0.0035
#   4 →  6 | -0.0036
#   5 →  7 | -0.0036
#   1 →  5 | -0.0036
#   4 →  7 | -0.0037
#  11 → 12 | -0.0038
#  11 → 13 | -0.0044
#   7 → 10 | -0.0045
#   6 → 10 | -0.0046
#  19 → 20 | -0.0061
#   3 →  6 | -0.0061
#   2 →  6 | -0.0061
#   3 →  7 | -0.0062
#   2 →  7 | -0.0063
#  18 → 20 | -0.0065
#   5 →  8 | -0.0066
#   4 →  8 | -0.0068
#   5 →  9 | -0.0068
#   4 →  9 | -0.0069
#   1 →  6 | -0.0071
#   1 →  7 | -0.0072
#   5 → 10 | -0.0081
#   4 → 10 | -0.0082
#   3 →  8 | -0.0093
#   2 →  8 | -0.0093
#   3 →  9 | -0.0095
#   2 →  9 | -0.0095
#   1 →  8 | -0.0103
#   1 →  9 | -0.0104
#  13 → 14 | -0.0105
#   3 → 10 | -0.0107
#   2 → 10 | -0.0108
#  12 → 14 | -0.0111
#  13 → 15 | -0.0111
#   1 → 10 | -0.0117
#  12 → 15 | -0.0117
#  17 → 18 | -0.0137
#  17 → 19 | -0.0142
#  16 → 18 | -0.0144
#  15 → 16 | -0.0145
#  16 → 19 | -0.0148
#  11 → 14 | -0.0149
#  15 → 17 | -0.0151
#  14 → 16 | -0.0151
#  11 → 15 | -0.0156
#  14 → 17 | -0.0157
#  17 → 20 | -0.0202
#  16 → 20 | -0.0208
#  13 → 16 | -0.0256
#  12 → 16 | -0.0262
#  13 → 17 | -0.0262
#  12 → 17 | -0.0268
#  15 → 18 | -0.0288
#  15 → 19 | -0.0292
#  14 → 18 | -0.0295
#  14 → 19 | -0.0299
#  11 → 16 | -0.0300
#  11 → 17 | -0.0307
#  15 → 20 | -0.0353
#  14 → 20 | -0.0360
#  13 → 18 | -0.0400
#  13 → 19 | -0.0404
#  12 → 18 | -0.0406
#  12 → 19 | -0.0410
#  11 → 18 | -0.0444
#  11 → 19 | -0.0448
#  13 → 20 | -0.0464
#  12 → 20 | -0.0470
#  11 → 20 | -0.0509
#  10 → 11 | -0.1153
#   9 → 11 | -0.1166
#   8 → 11 | -0.1167
#  10 → 12 | -0.1191
#  10 → 13 | -0.1197
#   7 → 11 | -0.1198
#   6 → 11 | -0.1199
#   9 → 12 | -0.1204
#   8 → 12 | -0.1206
#   9 → 13 | -0.1210
#   8 → 13 | -0.1212
#   5 → 11 | -0.1234
#   4 → 11 | -0.1235
#   7 → 12 | -0.1236
#   6 → 12 | -0.1238
#   7 → 13 | -0.1242
#   6 → 13 | -0.1244
#   3 → 11 | -0.1260
#   2 → 11 | -0.1261
#   1 → 11 | -0.1270
#   5 → 12 | -0.1272
#   4 → 12 | -0.1273
#   5 → 13 | -0.1278
#   4 → 13 | -0.1279
#   3 → 12 | -0.1299
#   2 → 12 | -0.1299
#  10 → 14 | -0.1302
#   3 → 13 | -0.1305
#   2 → 13 | -0.1305
#   1 → 12 | -0.1308
#  10 → 15 | -0.1309
#   1 → 13 | -0.1314
#   9 → 14 | -0.1315
#   8 → 14 | -0.1316
#   9 → 15 | -0.1321
#   8 → 15 | -0.1323
#   7 → 14 | -0.1347
#   6 → 14 | -0.1349
#   7 → 15 | -0.1354
#   6 → 15 | -0.1355
#   5 → 14 | -0.1383
#   4 → 14 | -0.1384
#   5 → 15 | -0.1390
#   4 → 15 | -0.1391
#   3 → 14 | -0.1409
#   2 → 14 | -0.1410
#   3 → 15 | -0.1416
#   2 → 15 | -0.1416
#   1 → 14 | -0.1419
#   1 → 15 | -0.1426
#  10 → 16 | -0.1453
#  10 → 17 | -0.1460
#   9 → 16 | -0.1466
#   8 → 16 | -0.1468
#   9 → 17 | -0.1472
#   8 → 17 | -0.1474
#   7 → 16 | -0.1498
#   6 → 16 | -0.1500
#   7 → 17 | -0.1505
#   6 → 17 | -0.1506
#   5 → 16 | -0.1534
#   4 → 16 | -0.1535
#   5 → 17 | -0.1540
#   4 → 17 | -0.1541
#   3 → 16 | -0.1561
#   2 → 16 | -0.1561
#   3 → 17 | -0.1567
#   2 → 17 | -0.1567
#   1 → 16 | -0.1570
#   1 → 17 | -0.1577
#  10 → 18 | -0.1597
#  10 → 19 | -0.1601
#   9 → 18 | -0.1610
#   8 → 18 | -0.1611
#   9 → 19 | -0.1614
#   8 → 19 | -0.1615
#   7 → 18 | -0.1642
#   6 → 18 | -0.1643
#   7 → 19 | -0.1646
#   6 → 19 | -0.1648
#  10 → 20 | -0.1662
#   9 → 20 | -0.1674
#   8 → 20 | -0.1676
#   5 → 18 | -0.1678
#   4 → 18 | -0.1679
#   5 → 19 | -0.1682
#   4 → 19 | -0.1683
#   3 → 18 | -0.1704
#   2 → 18 | -0.1705
#   7 → 20 | -0.1707
#   6 → 20 | -0.1708
#   3 → 19 | -0.1708
#   2 → 19 | -0.1709
#   1 → 18 | -0.1714
#   1 → 19 | -0.1718
#   5 → 20 | -0.1742
#   4 → 20 | -0.1744
#   3 → 20 | -0.1769
#   2 → 20 | -0.1769
#   1 → 20 | -0.1779
# -----------------------------------------------------

# %%
print(simoutidk.densities.keys())
simoutidk.plot_density('Gamma',density='Electron_density',title_diff=base_title,fontsizetitle=12)
simoutidk.plot_density('Gamma',density='Ionized_donor_density',title_diff=base_title,fontsizetitle=12)
# ax_carriers = simoutidk.bands['Gamma'].bandedges[0].plot()
# ax_bandedge,ax_carriers = simoutidk.plot_bandedge_with_density('Gamma',carrier='electron',title_diff=base_title,fontsizebase=12,fontsizetitle=14)
# simoutidk.electron_density.plot(ax=ax_carriers)
# Out:
# dict_keys(['Electron_density', 'Hole_density', 'Ionized_donor_density', 'Ionized_acceptor_density', 'n-Si-in-AlAs', 'n-Si-in-GaAs'])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (<Axes: title={'center': '10 periods, T =11 K, Alx =0.4, $t_{well}$= 7.5 nm, $t_{barrier}$=2.5 nm\n Nd = 2e+18 cm^-3, $E_{act,AlGaAs}=$ 0.007 eV, $E_{act,GaAs}=$ -10 eV'}, xlabel='Growth direction [nm]', ylabel='Energy relative to $E_F$ [eV]'>,
#  <Axes: ylabel='Ionized_donor_density [1e18 cm⁻³]'>)
