# %%
import nextnanopy as nn
import os
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
path_nextnanoprojects_tools = r"C:\Users\sp6497_a\nextnanopy_projects"

# %%
print(sys.path)
sys.path.append(path_nextnanoprojects_tools)
print(sys.path)
from nextnano_tools.helper_functions import build_output
from nextnano_tools.simstructs import SimOut, BandStructure, Eigenstate
# Out:
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin']
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\sp6497_a\\nextnanopy_projects']

# %%
bias = r'bias_00000'
quantum_region = r'Quantum\quantum_region'
quantum_band = r'kp8'
quantum_band_interactions = r'kp8_kp8'

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\Superlattice_N_Wells_AlGaAsGaAsx0p4nnp'
VB_cutoff = 0.0
simoutidk = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutidk.bands['CB'].sort_subbands(decreasing=False)
# simoutidk.bands['CB'].remove_subband(index=7)
# simoutidk.bands['CB'].remove_subband(index=6)
# simout.bands['CB'].
simoutidk.bands['CB'].plot_band(title_diff='checking SL',normalize_y=False)
simoutidk.bands['CB'].calc_intersubband_transitions()
simoutidk.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# simoutidk.optical_absorption.get_spectrum('TM-z').plot(show_grid=True,diff_title='ISB absorption T=295K')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\Superlattice_N_Wells_AlGaAsGaAsx0p4nnp'
#       2 VB_cutoff = 0.0
# ----> 3 simoutidk = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
#       4 simoutidk.bands['CB'].sort_subbands(decreasing=False)
#       5 # simoutidk.bands['CB'].remove_subband(index=7)
#       6 # simoutidk.bands['CB'].remove_subband(index=6)
#       7 # simout.bands['CB'].
#
# File ~\nextnanopy_projects\nextnano_tools\helper_functions.py:56, in build_output(outpath, quantum_region, quantum_band, quantum_band_interactions, bias, VB_cutoff, well_w)
#      54 band_edge = nn.DataFile(os.path.join(outpath, bias, 'bandedges.dat'), 'nextnano++')
#      55 quantum_sims_path = os.path.join(outpath, bias, quantum_region)
# ---> 56 energy_spectrum = nn.DataFile(os.path.join(quantum_sims_path, quantum_band, 'energy_spectrum_k00000.dat'), 'nextnano++')
#      57 probabilities = nn.DataFile(os.path.join(quantum_sims_path, quantum_band, 'probabilities_k00000.dat'), 'nextnano++')
#      58 transition_energies = nn.DataFile(os.path.join(quantum_sims_path, quantum_band_interactions, 'transition_energies_k00000.txt'), 'nextnano++')
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:419, in DataFile.__init__(self, fullpath, product, **loader_kwargs)
#     418 def __init__(self, fullpath, product=None, **loader_kwargs):
# --> 419     super().__init__(
#     420         fullpath, product=product, **loader_kwargs
#     421     )
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:382, in DataFileTemplate.__init__(self, fullpath, product, **loader_kwargs)
#     380 super().__init__(fullpath)
#     381 self.product = product
# --> 382 self.load(**loader_kwargs)
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\utils\misc.py:118, in message_decorator.<locals>.f(*args, **kwargs)
#     116 def f(*args, **kwargs):
#     117     show_message(init_msg)
# --> 118     result = method(*args, **kwargs)
#     119     show_message(end_msg)
#     120     return result
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:390, in DataFileTemplate.load(self, **loader_kwargs)
#     386 """
#     387 Find the loader and update the stored information with the loaded data
#     388 """
#     389 loader = self.get_loader()
# --> 390 df = loader(self.fullpath, **loader_kwargs)
#     391 self.update_with_datafile(df)
#     392 del df
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\nnp\outputs.py:16, in DataFile.__init__(self, fullpath, **loader_kwargs)
#      15 def __init__(self, fullpath, **loader_kwargs):
# ---> 16     super().__init__(fullpath, product="nextnano++")
#      17     self.load(**loader_kwargs)
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:382, in DataFileTemplate.__init__(self, fullpath, product, **loader_kwargs)
#     380 super().__init__(fullpath)
#     381 self.product = product
# --> 382 self.load(**loader_kwargs)
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\utils\misc.py:118, in message_decorator.<locals>.f(*args, **kwargs)
#     116 def f(*args, **kwargs):
#     117     show_message(init_msg)
# --> 118     result = method(*args, **kwargs)
#     119     show_message(end_msg)
#     120     return result
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:390, in DataFileTemplate.load(self, **loader_kwargs)
#     386 """
#     387 Find the loader and update the stored information with the loaded data
#     388 """
#     389 loader = self.get_loader()
# --> 390 df = loader(self.fullpath, **loader_kwargs)
#     391 self.update_with_datafile(df)
#     392 del df
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:822, in Dat.__init__(self, fullpath, **loader_kwargs)
#     820 def __init__(self, fullpath, **loader_kwargs):
#     821     super().__init__(fullpath)
# --> 822     self.load(**loader_kwargs)
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:825, in Dat.load(self, **loader_kwargs)
#     824 def load(self, **loader_kwargs):
# --> 825     self.load_metadata(**loader_kwargs)
#     826     self.load_data()
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:851, in Dat.load_metadata(self, FirstVarIsCoordFlag)
#     850 def load_metadata(self, FirstVarIsCoordFlag=True):
# --> 851     headers = self._get_headers()
#     852     self.metadata["headers"] = headers
#     853     self.metadata["skip_rows"] = len(headers)
#
# File c:\Users\sp6497_a\miniconda3\envs\nextnanodev\Lib\site-packages\nextnanopy\outputs.py:830, in Dat._get_headers(self)
#     828 def _get_headers(self):
#     829     headers = []
# --> 830     with open(self.fullpath, "r") as f:
#     831         for line in f:
#     832             try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\sp6497_a\\nextnano_outs\\Output\\Superlattice_N_Wells_AlGaAsGaAsx0p4nnp\\bias_00000\\Quantum\\quantum_region\\kp8\\energy_spectrum_k00000.dat'

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(7)'
VB_cutoff = -1
simoutidk = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutidk.bands['CB'].sort_subbands(decreasing=False)
simoutidk.bands['CB'].remove_subband(index=7)
simoutidk.bands['CB'].remove_subband(index=6)
# simout.bands['CB'].
simoutidk.bands['CB'].plot_band(title_diff='Schrodinger-Poisson well_l 12.75 nm well_r 7.5nm, barrier 2nm',normalize_y=False)
simoutidk.bands['CB'].calc_intersubband_transitions()
simoutidk.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
simoutidk.optical_absorption.get_spectrum('TM-z').plot(show_grid=True,diff_title='ISB absorption T=100K')
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(7)\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat', 'kp8_kp8']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# kp8_kp8
# [False, False, False]
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TM_z_eV.dat']
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   1 →  2 | -0.0128
#   4 →  5 | -0.0265
#   2 →  3 | -0.0497
#   1 →  3 | -0.0624
#   3 →  4 | -0.0789
#   3 →  5 | -0.1054
#   2 →  4 | -0.1286
#   1 →  4 | -0.1414
#   2 →  5 | -0.1551
#   1 →  5 | -0.1679
# -----------------------------------------------------
# <Axes: title={'center': 'ISB absorption T=100K'}, xlabel='Photon Energy (eV)', ylabel='Absorption (cm⁻¹)'>
