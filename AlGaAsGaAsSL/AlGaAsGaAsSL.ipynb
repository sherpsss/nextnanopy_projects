# %%
import nextnanopy as nn
import os
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
path_nextnanoprojects_tools = r"C:\Users\sp6497_a\nextnanopy_projects"

# %%
print(sys.path)
sys.path.append(path_nextnanoprojects_tools)
print(sys.path)
from nextnano_tools.helper_functions import build_output
from nextnano_tools.simstructs import SimOut, BandStructure, Eigenstate
# Out:
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin']
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\sp6497_a\\nextnanopy_projects']

# %%
bias = r'bias_00000'
quantum_region = r'Quantum\quantum_region'
quantum_band = r'Gamma'
quantum_band_interactions = r'Gamma_Gamma'

# %%
parent_dir = r"C:\Users\sp6497_a\OneDrive - Princeton University\nextnano_outs\Output\1Dsuperlattice_dispersion_smalltoying_nnp(5)"
VB_cutoff = -1.0
simoutidk = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14,model='gamma')
simoutidk.bands['CB'].sort_subbands(decreasing=False)
# simoutidk.bands['CB'].remove_subband(index=7)
# simoutidk.bands['CB'].remove_subband(index=6)
# simout.bands['CB'].
simoutidk.bands['CB'].plot_band(title_diff='checking SL',normalize_y=False,show_legend=False)
simoutidk.bands['CB'].calc_intersubband_transitions()
simoutidk.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")

# simoutidk.optical_absorption.get_spectrum('TM-z').plot(show_grid=True,diff_title='ISB absorption T=295K')
# Out:
# C:\Users\sp6497_a\OneDrive - Princeton University\nextnano_outs\Output\1Dsuperlattice_dispersion_smalltoying_nnp(5)\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_cm-1.dat', 'absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TM_z_cm-1.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'Gamma_Gamma', 'im_epsilon_spectrum_TE_y_cm-1.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TM_z_cm-1.dat', 'im_epsilon_spectrum_TM_z_eV.dat']
# absorption_coeff_spectrum_te_y_cm-1.dat
# [True, False, True]
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_cm-1.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# gamma_gamma
# [False, False, False]
# im_epsilon_spectrum_te_y_cm-1.dat
# [False, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_cm-1.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TM_z_eV.dat']
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   8 →  9 | -0.0001
#   6 →  7 | -0.0002
#   2 →  3 | -0.0002
#   4 →  5 | -0.0002
#  18 → 19 | -0.0004
#  16 → 17 | -0.0006
#  14 → 15 | -0.0006
#  12 → 13 | -0.0006
#   1 →  2 | -0.0011
#   1 →  3 | -0.0013
#   9 → 10 | -0.0019
#   8 → 10 | -0.0020
#   3 →  4 | -0.0032
#   2 →  4 | -0.0034
#   3 →  5 | -0.0034
#   2 →  5 | -0.0036
#   7 →  8 | -0.0044
#   7 →  9 | -0.0045
#   1 →  4 | -0.0045
#   6 →  8 | -0.0045
#   5 →  6 | -0.0046
#   6 →  9 | -0.0046
#   1 →  5 | -0.0047
#   5 →  7 | -0.0048
#   4 →  6 | -0.0048
#   4 →  7 | -0.0049
#  11 → 12 | -0.0049
#  11 → 13 | -0.0056
#   7 → 10 | -0.0063
#   6 → 10 | -0.0065
#   3 →  6 | -0.0080
#   3 →  7 | -0.0082
#   2 →  6 | -0.0082
#   2 →  7 | -0.0083
#  19 → 20 | -0.0089
#   5 →  8 | -0.0091
#   5 →  9 | -0.0092
#   1 →  6 | -0.0093
#   4 →  8 | -0.0093
#  18 → 20 | -0.0093
#   4 →  9 | -0.0094
#   1 →  7 | -0.0095
#   5 → 10 | -0.0111
#   4 → 10 | -0.0113
#   3 →  8 | -0.0125
#   3 →  9 | -0.0126
#   2 →  8 | -0.0127
#   2 →  9 | -0.0128
#  13 → 14 | -0.0134
#   1 →  8 | -0.0138
#   1 →  9 | -0.0139
#  13 → 15 | -0.0140
#  12 → 14 | -0.0140
#   3 → 10 | -0.0145
#  12 → 15 | -0.0146
#   2 → 10 | -0.0147
#   1 → 10 | -0.0158
#  15 → 16 | -0.0186
#  17 → 18 | -0.0187
#  11 → 14 | -0.0190
#  17 → 19 | -0.0191
#  15 → 17 | -0.0192
#  16 → 18 | -0.0192
#  14 → 16 | -0.0193
#  11 → 15 | -0.0196
#  16 → 19 | -0.0197
#  14 → 17 | -0.0198
#  17 → 20 | -0.0280
#  16 → 20 | -0.0286
#  13 → 16 | -0.0326
#  13 → 17 | -0.0332
#  12 → 16 | -0.0333
#  12 → 17 | -0.0339
#  15 → 18 | -0.0379
#  11 → 16 | -0.0382
#  15 → 19 | -0.0383
#  14 → 18 | -0.0385
#  11 → 17 | -0.0388
#  14 → 19 | -0.0389
#  15 → 20 | -0.0472
#  14 → 20 | -0.0478
#  13 → 18 | -0.0519
#  13 → 19 | -0.0523
#  12 → 18 | -0.0525
#  12 → 19 | -0.0530
#  11 → 18 | -0.0575
#  11 → 19 | -0.0579
#  13 → 20 | -0.0612
#  12 → 20 | -0.0619
#  11 → 20 | -0.0668
#  10 → 11 | -0.1013
#   9 → 11 | -0.1032
#   8 → 11 | -0.1033
#  10 → 12 | -0.1062
#  10 → 13 | -0.1069
#   7 → 11 | -0.1076
#   6 → 11 | -0.1078
#   9 → 12 | -0.1081
#   8 → 12 | -0.1082
#   9 → 13 | -0.1087
#   8 → 13 | -0.1089
#   5 → 11 | -0.1124
#   4 → 11 | -0.1126
#   7 → 12 | -0.1126
#   6 → 12 | -0.1128
#   7 → 13 | -0.1132
#   6 → 13 | -0.1134
#   3 → 11 | -0.1158
#   2 → 11 | -0.1160
#   1 → 11 | -0.1171
#   5 → 12 | -0.1173
#   4 → 12 | -0.1175
#   5 → 13 | -0.1180
#   4 → 13 | -0.1182
#  10 → 14 | -0.1203
#   3 → 12 | -0.1207
#  10 → 15 | -0.1209
#   2 → 12 | -0.1209
#   3 → 13 | -0.1214
#   2 → 13 | -0.1215
#   1 → 12 | -0.1220
#   9 → 14 | -0.1221
#   8 → 14 | -0.1222
#   1 → 13 | -0.1227
#   9 → 15 | -0.1228
#   8 → 15 | -0.1229
#   7 → 14 | -0.1266
#   6 → 14 | -0.1268
#   7 → 15 | -0.1272
#   6 → 15 | -0.1274
#   5 → 14 | -0.1314
#   4 → 14 | -0.1315
#   5 → 15 | -0.1320
#   4 → 15 | -0.1322
#   3 → 14 | -0.1348
#   2 → 14 | -0.1349
#   3 → 15 | -0.1354
#   2 → 15 | -0.1355
#   1 → 14 | -0.1361
#   1 → 15 | -0.1367
#  10 → 16 | -0.1395
#  10 → 17 | -0.1401
#   9 → 16 | -0.1414
#   8 → 16 | -0.1415
#   9 → 17 | -0.1420
#   8 → 17 | -0.1421
#   7 → 16 | -0.1459
#   6 → 16 | -0.1460
#   7 → 17 | -0.1464
#   6 → 17 | -0.1466
#   5 → 16 | -0.1506
#   4 → 16 | -0.1508
#   5 → 17 | -0.1512
#   4 → 17 | -0.1514
#   3 → 16 | -0.1540
#   2 → 16 | -0.1542
#   3 → 17 | -0.1546
#   2 → 17 | -0.1548
#   1 → 16 | -0.1553
#   1 → 17 | -0.1559
#  10 → 18 | -0.1588
#  10 → 19 | -0.1592
#   9 → 18 | -0.1606
#   8 → 18 | -0.1607
#   9 → 19 | -0.1611
#   8 → 19 | -0.1612
#   7 → 18 | -0.1651
#   6 → 18 | -0.1653
#   7 → 19 | -0.1655
#   6 → 19 | -0.1657
#  10 → 20 | -0.1681
#   5 → 18 | -0.1699
#   9 → 20 | -0.1700
#   4 → 18 | -0.1700
#   8 → 20 | -0.1701
#   5 → 19 | -0.1703
#   4 → 19 | -0.1705
#   3 → 18 | -0.1733
#   2 → 18 | -0.1734
#   3 → 19 | -0.1737
#   2 → 19 | -0.1739
#   7 → 20 | -0.1744
#   1 → 18 | -0.1746
#   6 → 20 | -0.1746
#   1 → 19 | -0.1750
#   5 → 20 | -0.1792
#   4 → 20 | -0.1794
#   3 → 20 | -0.1826
#   2 → 20 | -0.1828
#   1 → 20 | -0.1839
# -----------------------------------------------------

# %%
d_matrix = simoutidk.bands['CB'].get_dipole_matrix('TM_z')
print(d_matrix)
simoutidk.bands['CB'].plot_dipole_vs_energy('TM_z')

# with transition labels:
simoutidk.bands['CB'].plot_dipole_vs_energy('TM_z', label_transitions=True)
from nextnano_tools.helper_functions import plot_absorption_with_dipoles
spec = simoutidk.optical_absorption.get_spectrum('TM-z')
# spec.plot(show_grid=True, diff_title='ISB absorption T=295K')  # optional separate preview

ax, ax2 = plot_absorption_with_dipoles(simoutidk.bands['CB'], spec, 'TM_z',numin=600)
# Out:
# [[0.00000e+00 3.41738e+01 4.99754e+02 2.85445e+01 1.65390e+02 2.99455e+01
#   7.75710e+01 3.03840e+01 4.79835e+01 3.63638e+01 1.31530e-03 3.09183e-02
