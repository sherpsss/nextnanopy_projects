# %%
import nextnanopy as nn
import os
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
path_nextnanoprojects_tools = r"C:\Users\sp6497_a\nextnanopy_projects"

# %%
print(sys.path)
sys.path.append(path_nextnanoprojects_tools)
print(sys.path)
from nextnano_tools.helper_functions import build_output
from nextnano_tools.simstructs import SimOut, BandStructure, Eigenstate
# Out:
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin']
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\sp6497_a\\nextnanopy_projects']

# %%
bias = r'bias_00000'
quantum_region = r'Quantum\quantum_region'
quantum_band = r'Gamma'
quantum_band_interactions = r'Gamma_Gamma'

# %%
# %matplotlib widget
parent_dir = r"C:\Users\sp6497_a\OneDrive - Princeton University\nextnano_outs\Output\confirming_bound_to_continuum_InGaAs_InAlAs_InP_nnp(8)"

VB_cutoff = -1.0
simoutidk = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14,model='gamma')
simoutidk.bands['CB'].sort_subbands(decreasing=False)

simoutidk.bands['CB'].plot_band(title_diff='3.0 nm SW In0.53Ga0.47As/In0.53Al0.48As on InP',normalize_y=False,show_legend=False)
simoutidk.bands['CB'].calc_intersubband_transitions()
simoutidk.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")

simoutidk.optical_absorption.get_spectrum('TM-z').plot(show_grid=True)
# Out:
# C:\Users\sp6497_a\OneDrive - Princeton University\nextnano_outs\Output\confirming_bound_to_continuum_InGaAs_InAlAs_InP_nnp(8)\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'Gamma_Gamma', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# gamma_gamma
# [False, False, False]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TM_z_eV.dat']
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   8 →  9 | -0.0016
#   2 →  3 | -0.0179
#  10 → 11 | -0.0192
#   6 →  7 | -0.0198
#   4 →  5 | -0.0282
#  12 → 13 | -0.0382
#  18 → 19 | -0.0482
#  14 → 15 | -0.0518
#   3 →  4 | -0.0558
#  16 → 17 | -0.0561
#   2 →  4 | -0.0738
#   3 →  5 | -0.0840
#   2 →  5 | -0.1020
#   5 →  6 | -0.1162
#   5 →  7 | -0.1360
#   4 →  6 | -0.1444
#   4 →  7 | -0.1642
#   7 →  8 | -0.1887
#   7 →  9 | -0.1903
#   3 →  6 | -0.2002
#   6 →  8 | -0.2085
#   6 →  9 | -0.2101
#   2 →  6 | -0.2182
#   3 →  7 | -0.2200
#   2 →  7 | -0.2380
#   9 → 10 | -0.2483
#   8 → 10 | -0.2499
#   9 → 11 | -0.2675
#   8 → 11 | -0.2691
#  11 → 12 | -0.2886
#   1 →  2 | -0.3062
#  10 → 12 | -0.3078
#   1 →  3 | -0.3241
#   5 →  8 | -0.3247
#   5 →  9 | -0.3262
#  11 → 13 | -0.3268
#  13 → 14 | -0.3292
#  10 → 13 | -0.3460
#   4 →  8 | -0.3529
#   4 →  9 | -0.3545
#  12 → 14 | -0.3674
#  15 → 16 | -0.3742
#   1 →  4 | -0.3800
#  13 → 15 | -0.3810
#   1 →  5 | -0.4082
#   3 →  8 | -0.4087
#   3 →  9 | -0.4103
#  12 → 15 | -0.4192
#  14 → 16 | -0.4260
#  17 → 18 | -0.4261
#   2 →  8 | -0.4267
#   2 →  9 | -0.4282
#  15 → 17 | -0.4304
#   7 → 10 | -0.4386
#   7 → 11 | -0.4578
#   6 → 10 | -0.4584
#  17 → 19 | -0.4744
#   6 → 11 | -0.4776
#  14 → 17 | -0.4822
#  16 → 18 | -0.4823
#  19 → 20 | -0.4864
#   1 →  6 | -0.5244
#  16 → 19 | -0.5305
#  18 → 20 | -0.5346
#   1 →  7 | -0.5442
#   9 → 12 | -0.5561
#   8 → 12 | -0.5577
#   5 → 10 | -0.5746
#   5 → 11 | -0.5937
#   9 → 13 | -0.5943
#   8 → 13 | -0.5959
#   4 → 10 | -0.6028
#   4 → 11 | -0.6220
#  11 → 14 | -0.6560
#   3 → 10 | -0.6586
#  10 → 14 | -0.6752
#   2 → 10 | -0.6765
#   3 → 11 | -0.6778
#   2 → 11 | -0.6957
#  11 → 15 | -0.7078
#  10 → 15 | -0.7270
#   1 →  8 | -0.7329
#   1 →  9 | -0.7344
#   7 → 12 | -0.7464
#  13 → 16 | -0.7552
#   6 → 12 | -0.7662
#   7 → 13 | -0.7846
#  12 → 16 | -0.7934
#   6 → 13 | -0.8044
#  13 → 17 | -0.8114
#  12 → 17 | -0.8496
#  15 → 18 | -0.8565
#   5 → 12 | -0.8823
#  15 → 19 | -0.9047
#  14 → 18 | -0.9083
#   4 → 12 | -0.9106
#   5 → 13 | -0.9206
#   9 → 14 | -0.9235
#   8 → 14 | -0.9251
#   4 → 13 | -0.9488
#  14 → 19 | -0.9565
#  17 → 20 | -0.9608
#   3 → 12 | -0.9664
#   9 → 15 | -0.9753
#   8 → 15 | -0.9769
#   1 → 10 | -0.9827
#   2 → 12 | -0.9843
#   1 → 11 | -1.0019
#   3 → 13 | -1.0046
#  16 → 20 | -1.0169
#   2 → 13 | -1.0225
#  11 → 16 | -1.0820
#  10 → 16 | -1.1012
#   7 → 14 | -1.1138
#   6 → 14 | -1.1336
#  11 → 17 | -1.1382
#  10 → 17 | -1.1574
#   7 → 15 | -1.1656
#   6 → 15 | -1.1854
#  13 → 18 | -1.2375
#   5 → 14 | -1.2497
#  12 → 18 | -1.2757
#   4 → 14 | -1.2780
#  13 → 19 | -1.2857
#   1 → 12 | -1.2905
#   5 → 15 | -1.3016
#  12 → 19 | -1.3239
#   1 → 13 | -1.3287
#   4 → 15 | -1.3298
#   3 → 14 | -1.3338
#   9 → 16 | -1.3495
#   8 → 16 | -1.3511
#   2 → 14 | -1.3517
#   3 → 15 | -1.3856
#  15 → 20 | -1.3911
#   2 → 15 | -1.4035
#   9 → 17 | -1.4057
#   8 → 17 | -1.4072
#  14 → 20 | -1.4429
#   7 → 16 | -1.5398
#   6 → 16 | -1.5596
#  11 → 18 | -1.5643
#  10 → 18 | -1.5835
#   7 → 17 | -1.5959
#  11 → 19 | -1.6125
#   6 → 17 | -1.6157
#  10 → 19 | -1.6317
#   1 → 14 | -1.6579
#   5 → 16 | -1.6758
#   4 → 16 | -1.7040
#   1 → 15 | -1.7097
#   5 → 17 | -1.7319
#   3 → 16 | -1.7598
#   4 → 17 | -1.7601
#  13 → 20 | -1.7721
#   2 → 16 | -1.7778
#  12 → 20 | -1.8103
#   3 → 17 | -1.8159
#   9 → 18 | -1.8318
#   8 → 18 | -1.8333
#   2 → 17 | -1.8339
#   9 → 19 | -1.8800
#   8 → 19 | -1.8816
#   7 → 18 | -2.0220
#   6 → 18 | -2.0418
#   7 → 19 | -2.0703
#   1 → 16 | -2.0840
#   6 → 19 | -2.0901
#  11 → 20 | -2.0989
#  10 → 20 | -2.1181
#   1 → 17 | -2.1401
#   5 → 18 | -2.1580
#   4 → 18 | -2.1862
#   5 → 19 | -2.2063
#   4 → 19 | -2.2345
#   3 → 18 | -2.2421
#   2 → 18 | -2.2600
#   3 → 19 | -2.2903
#   2 → 19 | -2.3083
#   9 → 20 | -2.3664
#   8 → 20 | -2.3680
#   7 → 20 | -2.5567
#   1 → 18 | -2.5662
#   6 → 20 | -2.5765
#   1 → 19 | -2.6145
#   5 → 20 | -2.6927
#   4 → 20 | -2.7209
#   3 → 20 | -2.7767
#   2 → 20 | -2.7947
#   1 → 20 | -3.1008
# -----------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <Axes: xlabel='Photon Energy (eV)', ylabel='Absorption (cm⁻¹)'>

# %%
d_matrix = simoutidk.bands['CB'].get_dipole_matrix('TM_z')
print(d_matrix)
simoutidk.bands['CB'].plot_dipole_vs_energy('TM_z')

# with transition labels:
simoutidk.bands['CB'].plot_dipole_vs_energy('TM_z', label_transitions=True)
from nextnano_tools.helper_functions import plot_absorption_with_dipoles
spec = simoutidk.optical_absorption.get_spectrum('TM-z')
# spec.plot(show_grid=True, diff_title='ISB absorption T=295K')  # optional separate preview

ax, ax2 = plot_absorption_with_dipoles(simoutidk.bands['CB'], spec, 'TM_z',numin=600)
# Out:
# [[0.00000e+00 2.16619e-06 1.03753e+00 2.18180e-06 9.36320e-01 2.09524e-06
#   3.42388e-01 7.91096e-02 2.05115e-06 1.86555e-02 2.03230e-06 3.15523e-03
