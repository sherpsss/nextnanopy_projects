# %%
import nextnanopy as nn
import os
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
path_nextnanoprojects_tools = r"C:\Users\sp6497_a\nextnanopy_projects"

# %%
print(sys.path)
sys.path.append(path_nextnanoprojects_tools)
print(sys.path)
from nextnano_tools.helper_functions import build_output
from nextnano_tools.simstructs import SimOut, BandStructure, Eigenstate
# Out:
# ['c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\python313.zip', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\DLLs', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev', '', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\sp6497_a\\miniconda3\\envs\\nextnanodev\\Lib\\site-packages\\Pythonwin']
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_widths_for_DW(5)'
VB_cutoff = 2
bias = r'bias_00000'
quantum_region = r'Quantum\quantum_region'
quantum_band = r'kp8'
quantum_band_interactions = r'kp8_kp8'
simout = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14.0)
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_widths_for_DW(5)\bias_00000\OpticsQuantum\quantum_region

# %%
simout.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simout.bands['CB'].plot_band(title_diff = '14 nm well',normalize_y=True)
simout.bands['CB'].calc_intersubband_transitions()
# Out:
# array([[ 0.        , -0.05714435, -0.14336463, -0.24650821, -0.31984669,
#         -0.3224394 ],
#        [ 0.05714435,  0.        , -0.08622029, -0.18936387, -0.26270235,
#         -0.26529506],
#        [ 0.14336463,  0.08622029,  0.        , -0.10314358, -0.17648206,
#         -0.17907477],
#        [ 0.24650821,  0.18936387,  0.10314358,  0.        , -0.07333848,
#         -0.07593119],
#        [ 0.31984669,  0.26270235,  0.17648206,  0.07333848,  0.        ,
#         -0.00259271],
#        [ 0.3224394 ,  0.26529506,  0.17907477,  0.07593119,  0.00259271,
#          0.        ]])

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_match_162meV_transition(2)'
VB_cutoff = 2
simout2 = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,8.5)
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_match_162meV_transition(2)\bias_00000\OpticsQuantum\quantum_region

# %%
simout2.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simout2.bands['CB'].plot_band(title_diff='8.5 nm well',normalize_y=True)
simout2.bands['CB'].calc_intersubband_transitions()
# Out:
# array([[ 0.        , -0.11737791, -0.26433915, -0.29764075, -0.30008177,
#         -0.3218729 ],
#        [ 0.11737791,  0.        , -0.14696124, -0.18026284, -0.18270386,
#         -0.204495  ],
#        [ 0.26433915,  0.14696124,  0.        , -0.0333016 , -0.03574262,
#         -0.05753376],
#        [ 0.29764075,  0.18026284,  0.0333016 ,  0.        , -0.00244102,
#         -0.02423215],
#        [ 0.30008177,  0.18270386,  0.03574262,  0.00244102,  0.        ,
#         -0.02179114],
#        [ 0.3218729 ,  0.204495  ,  0.05753376,  0.02423215,  0.02179114,
#          0.        ]])

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW(2)'
VB_cutoff = 2
simout2 = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simout2.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simout2.bands['CB'].plot_band(title_diff='barrier wide enough not coupled wells',normalize_y=True)
simout2.bands['CB'].calc_intersubband_transitions()
simout2.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW(2)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   4 →  5 | -0.0020
#   1 →  2 | -0.0240
#   7 →  8 | -0.0323
#   2 →  3 | -0.0331
#   6 →  7 | -0.0418
#   1 →  3 | -0.0571
#   6 →  8 | -0.0741
#   3 →  4 | -0.0842
#   3 →  5 | -0.0862
#   5 →  6 | -0.1031
#   4 →  6 | -0.1051
#   2 →  4 | -0.1174
#   2 →  5 | -0.1194
#   1 →  4 | -0.1414
#   1 →  5 | -0.1434
#   5 →  7 | -0.1450
#   4 →  7 | -0.1470
#   5 →  8 | -0.1773
#   4 →  8 | -0.1793
#   3 →  6 | -0.1894
#   2 →  6 | -0.2225
#   3 →  7 | -0.2312
#   1 →  6 | -0.2465
#   3 →  8 | -0.2635
#   2 →  7 | -0.2643
#   1 →  7 | -0.2884
#   2 →  8 | -0.2967
#   1 →  8 | -0.3207
# -----------------------------------------------------

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW(3)'
VB_cutoff = 2
simout2 = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simout2.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simout2.bands['CB'].plot_band(title_diff='barrier 2nm',normalize_y=True)
simout2.bands['CB'].calc_intersubband_transitions()
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW(3)\bias_00000\OpticsQuantum\quantum_region
# array([[ 0.        , -0.02372712, -0.05733675, -0.13261472, -0.15342102,
#         -0.2467142 , -0.29861902, -0.32179678],
#        [ 0.02372712,  0.        , -0.03360963, -0.1088876 , -0.1296939 ,
#         -0.22298709, -0.27489191, -0.29806966],
#        [ 0.05733675,  0.03360963,  0.        , -0.07527797, -0.09608427,
#         -0.18937746, -0.24128228, -0.26446003],
#        [ 0.13261472,  0.1088876 ,  0.07527797,  0.        , -0.0208063 ,
#         -0.11409949, -0.16600431, -0.18918206],
#        [ 0.15342102,  0.1296939 ,  0.09608427,  0.0208063 ,  0.        ,
#         -0.09329319, -0.14519801, -0.16837576],
#        [ 0.2467142 ,  0.22298709,  0.18937746,  0.11409949,  0.09329319,
#          0.        , -0.05190482, -0.07508257],
#        [ 0.29861902,  0.27489191,  0.24128228,  0.16600431,  0.14519801,
#          0.05190482,  0.        , -0.02317775],
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW_grid_keep_interpolation(1)'
VB_cutoff = 2
simout2 = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simout2.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simout2.bands['CB'].plot_band(title_diff='barrier 2nm',normalize_y=True)
simout2.bands['CB'].calc_intersubband_transitions()
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW_grid_keep_interpolation(1)\bias_00000\OpticsQuantum\quantum_region
# array([[ 0.        , -0.02357739, -0.05682578, -0.1306166 , -0.150902  ,
#         -0.24077458, -0.291884  ],
#        [ 0.02357739,  0.        , -0.03324839, -0.10703922, -0.12732461,
#         -0.2171972 , -0.26830661],
#        [ 0.05682578,  0.03324839,  0.        , -0.07379082, -0.09407622,
#         -0.1839488 , -0.23505822],
#        [ 0.1306166 ,  0.10703922,  0.07379082,  0.        , -0.02028539,
#         -0.11015798, -0.1612674 ],
#        [ 0.150902  ,  0.12732461,  0.09407622,  0.02028539,  0.        ,
#         -0.08987259, -0.140982  ],
#        [ 0.24077458,  0.2171972 ,  0.1839488 ,  0.11015798,  0.08987259,
#          0.        , -0.05110942],
#        [ 0.291884  ,  0.26830661,  0.23505822,  0.1612674 ,  0.140982  ,
#          0.05110942,  0.        ]])

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW_grid_keep_interpolation(2)'
VB_cutoff = -1
simout2 = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simout2.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simout2.bands['CB'].plot_band(title_diff='barrier 2nm doped with adjusted grid')
simout2.bands['CB'].calc_intersubband_transitions()
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW_grid_keep_interpolation(2)\bias_00000\OpticsQuantum\quantum_region
# array([[ 0.        , -0.00949533, -0.05314057, -0.11879253, -0.14198472,
#         -0.23215118, -0.2604352 ],
#        [ 0.00949533,  0.        , -0.04364524, -0.1092972 , -0.13248939,
#         -0.22265585, -0.25093987],
#        [ 0.05314057,  0.04364524,  0.        , -0.06565195, -0.08884414,
#         -0.17901061, -0.20729463],
#        [ 0.11879253,  0.1092972 ,  0.06565195,  0.        , -0.02319219,
#         -0.11335866, -0.14164267],
#        [ 0.14198472,  0.13248939,  0.08884414,  0.02319219,  0.        ,
#         -0.09016647, -0.11845048],
#        [ 0.23215118,  0.22265585,  0.17901061,  0.11335866,  0.09016647,
#          0.        , -0.02828402],
#        [ 0.2604352 ,  0.25093987,  0.20729463,  0.14164267,  0.11845048,
#          0.02828402,  0.        ]])

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW_grid_keep_interpolation(4)'
VB_cutoff = -1
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='0.25 nm fine res')
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAs_GaAs_DW_grid_keep_interpolation(4)\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat', 'kp8_kp8']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# kp8_kp8
# [False, False, False]
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAsGaAs_DW_shift_ISBT(6)'
VB_cutoff = 2
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='well l 11.15 nm',normalize_y=True)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAsGaAs_DW_shift_ISBT(6)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   4 →  5 | -0.0021
#   6 →  7 | -0.0103
#   1 →  2 | -0.0360
#   2 →  3 | -0.0440
#   1 →  3 | -0.0800
#   5 →  6 | -0.1104
#   4 →  6 | -0.1125
#   3 →  4 | -0.1149
#   3 →  5 | -0.1170
#   5 →  7 | -0.1207
#   4 →  7 | -0.1228
#   2 →  4 | -0.1589
#   2 →  5 | -0.1610
#   1 →  4 | -0.1949
#   1 →  5 | -0.1970
#   3 →  6 | -0.2273
#   3 →  7 | -0.2377
#   2 →  6 | -0.2714
#   2 →  7 | -0.2817
#   1 →  6 | -0.3074
#   1 →  7 | -0.3177
# -----------------------------------------------------

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAsGaAs_DW_shift_ISBT(7)'
VB_cutoff = 2
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='well l 11.15 nm, barrier 2nm',normalize_y=True)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAsGaAs_DW_shift_ISBT(7)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   6 →  7 | -0.0064
#   4 →  5 | -0.0330
#   1 →  2 | -0.0356
#   2 →  3 | -0.0455
#   1 →  3 | -0.0811
#   5 →  6 | -0.0979
#   3 →  4 | -0.1018
#   5 →  7 | -0.1044
#   4 →  6 | -0.1309
#   3 →  5 | -0.1348
#   4 →  7 | -0.1374
#   2 →  4 | -0.1472
#   2 →  5 | -0.1802
#   1 →  4 | -0.1828
#   1 →  5 | -0.2158
#   3 →  6 | -0.2327
#   3 →  7 | -0.2391
#   2 →  6 | -0.2781
#   2 →  7 | -0.2846
#   1 →  6 | -0.3137
#   1 →  7 | -0.3202
# -----------------------------------------------------

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAsGaAs_DW_shift_ISBT(8)'
VB_cutoff = -1
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='well l 11.15 nm, barrier 2nm, self consistent')
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAsGaAs_DW_shift_ISBT(8)\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat', 'kp8_kp8']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# kp8_kp8
# [False, False, False]
# ...

# %%
simoutsmallgrid.optical_absorption
# Out:
# <OpticalAbsorption: ['TE-y', 'TM-z']>

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\AlGaAsGaAs_DW_shift_ISBT(11)'
VB_cutoff = -1
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='10 percent reduction well l 11.15 nm, barrier 2nm, self consistent')
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\AlGaAsGaAs_DW_shift_ISBT(11)\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat', 'kp8_kp8']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# kp8_kp8
# [False, False, False]
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(1)'
VB_cutoff = 1
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='well_l 13.5 nm well_r 7.5nm, barrier 15nm, self consistent',normalize_y=True)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(1)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   4 →  5 | -0.0174
#   2 →  3 | -0.0289
#   1 →  2 | -0.0316
#   1 →  3 | -0.0605
#   3 →  4 | -0.0906
#   3 →  5 | -0.1080
#   2 →  4 | -0.1196
#   2 →  5 | -0.1370
#   1 →  4 | -0.1511
#   1 →  5 | -0.1685
# -----------------------------------------------------

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(2)'
VB_cutoff = 1
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='well_l 12.5 nm well_r 7.5nm, barrier 15nm, self consistent',normalize_y=True)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(2)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   4 →  5 | -0.0029
#   1 →  2 | -0.0287
#   2 →  3 | -0.0394
#   1 →  3 | -0.0681
#   3 →  4 | -0.0976
#   3 →  5 | -0.1005
#   2 →  4 | -0.1370
#   2 →  5 | -0.1399
#   1 →  4 | -0.1657
#   1 →  5 | -0.1685
# -----------------------------------------------------

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(5)'
VB_cutoff = 1
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='well_l 12.75 nm well_r 7.5nm, barrier 15nm, self consistent',normalize_y=True)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(5)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   4 →  5 | -0.0025
#   1 →  2 | -0.0295
#   2 →  3 | -0.0366
#   6 →  7 | -0.0374
#   1 →  3 | -0.0661
#   3 →  4 | -0.0979
#   3 →  5 | -0.1004
#   5 →  6 | -0.1093
#   4 →  6 | -0.1118
#   2 →  4 | -0.1345
#   2 →  5 | -0.1370
#   5 →  7 | -0.1468
#   4 →  7 | -0.1492
#   1 →  4 | -0.1639
#   1 →  5 | -0.1664
#   3 →  6 | -0.2097
#   2 →  6 | -0.2463
#   3 →  7 | -0.2471
#   1 →  6 | -0.2758
#   2 →  7 | -0.2837
#   1 →  7 | -0.3132
# -----------------------------------------------------

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(6)'
VB_cutoff = 1
simoutnonhybridized = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutnonhybridized.bands['CB'].sort_subbands(decreasing=False)
simoutnonhybridized.bands['CB'].remove_subband(index=7)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutnonhybridized.bands['CB'].plot_band(title_diff='well_l 12.75 nm well_r 7.5nm, barrier 2nm, Schrodinger only',normalize_y=True)
simoutnonhybridized.bands['CB'].calc_intersubband_transitions()
simoutnonhybridized.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(6)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   4 →  5 | -0.0257
#   1 →  2 | -0.0291
#   2 →  3 | -0.0374
#   1 →  3 | -0.0665
#   3 →  4 | -0.0872
#   5 →  6 | -0.0994
#   3 →  5 | -0.1128
#   2 →  4 | -0.1246
#   4 →  6 | -0.1251
#   2 →  5 | -0.1503
#   1 →  4 | -0.1537
#   1 →  5 | -0.1793
#   3 →  6 | -0.2122
#   2 →  6 | -0.2497
#   1 →  6 | -0.2787
# -----------------------------------------------------

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(7)'
VB_cutoff = -1
simoutidk = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutidk.bands['CB'].sort_subbands(decreasing=False)
simoutidk.bands['CB'].remove_subband(index=7)
simoutidk.bands['CB'].remove_subband(index=6)
# simout.bands['CB'].
simoutidk.bands['CB'].plot_band(title_diff='Schrodinger-Poisson well_l 12.75 nm well_r 7.5nm, barrier 2nm',normalize_y=False)
simoutidk.bands['CB'].calc_intersubband_transitions()
simoutidk.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(7)\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat', 'kp8_kp8']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# kp8_kp8
# [False, False, False]
# ...

# %%
simoutidk.bands['CB']
simoutidk.bands['CB'].remove_subband(index=6)
simoutidk.bands['CB'].plot_band()
# Out:
# <Axes: title={'center': 'CB band structure'}, xlabel='Growth direction (nm)', ylabel='Energy (eV)'>

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(8)'
VB_cutoff = -1
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='10 percent reduction layer thickness',normalize_y=False)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized(8)\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat', 'kp8_kp8']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# kp8_kp8
# [False, False, False]
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized_test_295K_absorption'
VB_cutoff = -1
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
simoutsmallgrid.bands['CB'].remove_subband(index=7)
simoutsmallgrid.bands['CB'].remove_subband(index=6)
simoutsmallgrid.bands['CB'].plot_band(title_diff='T=295K well_l 12.75 nm, well_r 7.5nm, barrier 2nm, self consistent',normalize_y=False)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized_test_295K_absorption\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat', 'kp8_kp8']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# kp8_kp8
# [False, False, False]
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\12.75nm_7.5nm_wells_spacingcheck(15)'
VB_cutoff = 2
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='15nm repeat separation',show_legend=False,normalize_y=True)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\12.75nm_7.5nm_wells_spacingcheck(15)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   1 →  2 | -0.0000
#   3 →  4 | -0.0000
#   5 →  6 | -0.0000
#   7 →  8 | -0.0000
#   9 → 10 | -0.0000
#  11 → 12 | -0.0002
#   8 →  9 | -0.0257
#   7 →  9 | -0.0257
#   8 → 10 | -0.0257
#   7 → 10 | -0.0257
#   2 →  3 | -0.0291
#   1 →  3 | -0.0291
#   2 →  4 | -0.0291
#   1 →  4 | -0.0291
#   4 →  5 | -0.0374
#   3 →  5 | -0.0374
#   4 →  6 | -0.0374
#   3 →  6 | -0.0374
#   2 →  5 | -0.0665
#   1 →  5 | -0.0665
#   2 →  6 | -0.0665
#   1 →  6 | -0.0665
#   6 →  7 | -0.0872
#   5 →  7 | -0.0872
#   6 →  8 | -0.0872
#   5 →  8 | -0.0872
#  10 → 11 | -0.0993
#   9 → 11 | -0.0993
#  10 → 12 | -0.0995
#   9 → 12 | -0.0995
#   6 →  9 | -0.1128
#   5 →  9 | -0.1128
#   6 → 10 | -0.1129
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\12.75nm_7.5nm_wells_spacingcheck(16)'
VB_cutoff = 2
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='test hybridizing 12.75nm well, 7.5 nm well,20nm separation',normalize_y=False)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\12.75nm_7.5nm_wells_spacingcheck(16)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   1 →  2 | -0.0000
#   3 →  4 | -0.0000
#   5 →  6 | -0.0000
#   7 →  8 | -0.0000
#   9 → 10 | -0.0000
#  11 → 12 | -0.0001
#   8 →  9 | -0.0257
#   7 →  9 | -0.0257
#   8 → 10 | -0.0257
#   7 → 10 | -0.0257
#   2 →  3 | -0.0291
#   1 →  3 | -0.0291
#   2 →  4 | -0.0291
#   1 →  4 | -0.0291
#   4 →  5 | -0.0374
#   3 →  5 | -0.0374
#   4 →  6 | -0.0374
#   3 →  6 | -0.0374
#   2 →  5 | -0.0665
#   1 →  5 | -0.0665
#   2 →  6 | -0.0665
#   1 →  6 | -0.0665
#   6 →  7 | -0.0872
#   5 →  7 | -0.0872
#   6 →  8 | -0.0872
#   5 →  8 | -0.0872
#  10 → 11 | -0.0994
#   9 → 11 | -0.0994
#  10 → 12 | -0.0994
#   9 → 12 | -0.0994
#   6 →  9 | -0.1128
#   5 →  9 | -0.1128
#   6 → 10 | -0.1128
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\12.75nm_7.5nm_wells_spacingcheck(17)'
VB_cutoff = 2
simoutsmallgrid = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutsmallgrid.bands['CB'].sort_subbands(decreasing=False)
# simout.bands['CB'].remove_subband(index=5)
# simout.bands['CB'].
simoutsmallgrid.bands['CB'].plot_band(title_diff='3nm repeat separation',show_legend=False,normalize_y=True)
simoutsmallgrid.bands['CB'].calc_intersubband_transitions()
simoutsmallgrid.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\12.75nm_7.5nm_wells_spacingcheck(17)\bias_00000\OpticsQuantum\quantum_region
# Intersubband transition energies — CB
# -----------------------------------------------------
#  i → j | ΔE (eV)
# -----------------------------------------------------
#   1 →  2 | -0.0002
#   3 →  4 | -0.0007
#   5 →  6 | -0.0012
#   7 →  8 | -0.0064
#  11 → 12 | -0.0083
#   9 → 10 | -0.0083
#   8 →  9 | -0.0194
#   7 →  9 | -0.0258
#   8 → 10 | -0.0277
#   2 →  3 | -0.0286
#   1 →  3 | -0.0288
#   2 →  4 | -0.0293
#   1 →  4 | -0.0294
#   7 → 10 | -0.0340
#   4 →  5 | -0.0366
#   3 →  5 | -0.0373
#   4 →  6 | -0.0378
#   3 →  6 | -0.0384
#   2 →  5 | -0.0659
#   1 →  5 | -0.0660
#   2 →  6 | -0.0670
#   1 →  6 | -0.0672
#   6 →  7 | -0.0831
#   5 →  7 | -0.0843
#   6 →  8 | -0.0895
#   5 →  8 | -0.0906
#  10 → 11 | -0.0918
#  10 → 12 | -0.1000
#   9 → 11 | -0.1001
#   9 → 12 | -0.1083
#   6 →  9 | -0.1089
#   5 →  9 | -0.1100
#   6 → 10 | -0.1172
# ...

# %%
parent_dir = r'C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized_test_295K_absorption'
VB_cutoff = -1
simoutidk = build_output(parent_dir,quantum_region,quantum_band,quantum_band_interactions,bias,VB_cutoff,14)
simoutidk.bands['CB'].sort_subbands(decreasing=False)
simoutidk.bands['CB'].remove_subband(index=7)
simoutidk.bands['CB'].remove_subband(index=6)
# simout.bands['CB'].
simoutidk.bands['CB'].plot_band(title_diff='Schrodinger-Poisson well_l 12.75 nm well_r 7.5nm, barrier 2nm',normalize_y=False)
simoutidk.bands['CB'].calc_intersubband_transitions()
simoutidk.bands['CB'].display_intersubband_transitions(upward_only=True,sort_by_deltaE="descending")
simoutidk.optical_absorption.get_spectrum('TM-z').plot(show_grid=True,diff_title='ISB absorption T=295K')
# Out:
# C:\Users\sp6497_a\nextnano_outs\Output\middle_7.5nm_well_hybridized_test_295K_absorption\bias_00000\OpticsQuantum\quantum_region
# reached optics path
# ['absorption_coeff_spectrum_TE_y_eV.dat', 'absorption_coeff_spectrum_TE_y_nm.dat', 'absorption_coeff_spectrum_TM_z_eV.dat', 'absorption_coeff_spectrum_TM_z_nm.dat', 'im_epsilon_spectrum_TE_y_eV.dat', 'im_epsilon_spectrum_TE_y_nm.dat', 'im_epsilon_spectrum_TM_z_eV.dat', 'im_epsilon_spectrum_TM_z_nm.dat', 'kp8_kp8']
# absorption_coeff_spectrum_te_y_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_te_y_nm.dat
# [True, False, True]
# absorption_coeff_spectrum_tm_z_ev.dat
# [True, True, True]
# absorption_coeff_spectrum_tm_z_nm.dat
# [True, False, True]
# im_epsilon_spectrum_te_y_ev.dat
# [False, True, True]
# im_epsilon_spectrum_te_y_nm.dat
# [False, False, True]
# im_epsilon_spectrum_tm_z_ev.dat
# [False, True, True]
# im_epsilon_spectrum_tm_z_nm.dat
# [False, False, True]
# kp8_kp8
# [False, False, False]
# ...
