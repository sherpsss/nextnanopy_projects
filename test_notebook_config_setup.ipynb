# %%
import nextnanopy as nn

# %%
nn.config
# Out:
# NNConfig(C:\Users\splatt\.nextnanopy-config)
# [nextnano++]
# exe = C:\Program Files\nextnano\2025_09_18\nextnano++\bin\nextnano++_Intel_64bit.exe
# license = C:\Users\splatt\Documents\nextnano\activated_license\License_nnp.lic
# database = C:\Program Files\nextnano\2025_09_18\nextnano++\database\database.nnp
# outputdirectory = C:\Users\splatt\Documents\nextnano\Output
# threads = 0
# [nextnano3]
# exe = C:\Program Files\nextnano\2025_09_18\nextnano3\bin\nextnano3_Intel_ifx.exe
# license = C:\Users\splatt\Documents\nextnano\activated_license\License_nnp.lic
# database = C:\Program Files\nextnano\2025_09_18\nextnano3\database\database.nn3
# threads = 0
# outputdirectory = C:\Users\splatt\Documents\nextnano\Output
# debuglevel = 0
# cancel = -1
# softkill = -1
# [nextnano.NEGF]
# exe = C:\Program Files\nextnano\2025_09_18\nextnano.NEGF\bin\nextnano.NEGF_win.exe
# license = C:\Users\splatt\Documents\nextnano\activated_license\License_nnNEGF.lic
# ...

# %%
my_input = nn.InputFile('example.in')
my_input.config
# Out:
# NNConfig(C:\Users\splatt\.nextnanopy-config)
# [nextnano++]
# exe = C:\Program Files\nextnano\2025_09_18\nextnano++\bin\nextnano++_Intel_64bit.exe
# license = C:\Users\splatt\Documents\nextnano\activated_license\License_nnp.lic
# database = C:\Program Files\nextnano\2025_09_18\nextnano++\database\database.nnp
# outputdirectory = C:\Users\splatt\Documents\nextnano\Output
# threads = 0
# [nextnano3]
# exe = C:\Program Files\nextnano\2025_09_18\nextnano3\bin\nextnano3_Intel_ifx.exe
# license = C:\Users\splatt\Documents\nextnano\activated_license\License_nnp.lic
# database = C:\Program Files\nextnano\2025_09_18\nextnano3\database\database.nn3
# threads = 0
# outputdirectory = C:\Users\splatt\Documents\nextnano\Output
# debuglevel = 0
# cancel = -1
# softkill = -1
# [nextnano.NEGF]
# exe = C:\Program Files\nextnano\2025_09_18\nextnano.NEGF\bin\nextnano.NEGF_win.exe
# license = C:\Users\splatt\Documents\nextnano\activated_license\License_nnNEGF.lic
# ...

# %%
my_input.execute()
# Out:
# ...
# PREPARING...
# ...
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ...
# RUNNING..
# ...
# Starting execution as:
# C:\Program Files\nextnano\2025_09_18\nextnano++\bin\nextnano++_Intel_64bit.exe --license C:\Users\splatt\Documents\nextnano\activated_license\License_nnp.lic --database C:\Program Files\nextnano\2025_09_18\nextnano++\database\database.nnp --threads 0 --outputdirectory C:\Users\splatt\Documents\nextnano\Output\example --noautooutdir c:\Users\splatt\nextnanopy_projects\example.in
#
# nextnano++ 2.3.9 from 2025-09-14 (library 2025-07-29)
# ...
# COPYRIGHT NOTICE
# ...
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# ...

# %%
my_input.execute(outputdirectory=r"C:\Users\splatt\Downloads", threads=4)
# Out:
# ...
# PREPARING...
# ...
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ...
# RUNNING..
# ...
# Starting execution as:
# C:\Program Files\nextnano\2025_09_18\nextnano++\bin\nextnano++_Intel_64bit.exe --license C:\Users\splatt\Documents\nextnano\activated_license\License_nnp.lic --database C:\Program Files\nextnano\2025_09_18\nextnano++\database\database.nnp --threads 4 --outputdirectory C:\Users\splatt\Downloads\example --noautooutdir c:\Users\splatt\nextnanopy_projects\example.in
#
# nextnano++ 2.3.9 from 2025-09-14 (library 2025-07-29)
# ...
# COPYRIGHT NOTICE
# ...
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# ...
